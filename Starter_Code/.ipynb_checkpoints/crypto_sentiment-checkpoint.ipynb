# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Margee\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()

news_api_key = os.getenv('NEWS_API')

# %%
# Create a newsapi client
news_api_client = NewsApiClient(api_key=news_api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_articles = news_api_client.get_everything(
    q='bitcoin',
    language='en'
)
bitcoin_articles['totalResults']
# Out:
# 6436

# %%
# Fetch the Ethereum news articles
ethereum_articles = news_api_client.get_everything(
    q='ethereum',
    language='en'
)
ethereum_articles['totalResults']
# Out:
# 2807

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_sentiments_df = pd.DataFrame(bitcoin_sentiments)
bitcoin_sentiments_df
# Out:
#                                                  text        date  compound  \
# 0   Musk.MARK RALSTON/AFP via Getty Images\r\nElon...  2021-12-29    0.3612
# 1   Image source, AFP via Getty Images\r\nImage ca...  2021-12-12   -0.4019
# 2   The plant opening northeast of Niagara Falls t...  2021-12-06    0.0000
# 3   Dec 23 (Reuters) - The U.S. Securities and Exc...  2021-12-23    0.5859
# 4   People aren't done hijacking major politicians...  2021-12-12    0.5267
# 5   Representation of cryptocurrency bitcoin is se...  2021-12-12    0.0000
# 6   (Reuters) - A computer scientist who has claim...  2021-12-06    0.0000
# 7   A representation of the virtual cryptocurrency...  2021-12-28    0.0000
# 8   Dec 4 (Reuters) - Bitcoin dropped 8.4% to $49,...  2021-12-04   -0.3818
# 9   Posted \r\nBitcoin shed a fifth of its value o...  2021-12-04    0.5106
# 10  Posted \r\nBitcoin shed a fifth of its value o...  2021-12-04    0.5106
# 11  Dec 3 (Reuters) - Bitcoin plunged 5.5% to $53,...  2021-12-03   -0.3818
# 12  A representation of the virtual cryptocurrency...  2021-12-04    0.0000
# 13  Bitcoin tumbled almost 5% on Monday as the sta...  2021-12-06   -0.3182
# 14  Posted \r\nA computer scientist who has claime...  2021-12-09    0.0000
# 15  Posted \r\nA computer scientist who has claime...  2021-12-09    0.0000
# 16  In a disclosure that should surprise no one, t...  2021-12-08    0.4588
# 17  "Bitcoin mining is a process of competitively ...  2021-12-11    0.2500
# 18  bitcoin daily\r\nCryptocurrencies were sold ha...  2021-12-05   -0.7964
# 19  Is Satoshi's identity finally revealed?\r\nGet...  2021-12-06    0.0000
#
#     positive  negative  neutral
# 0      0.077     0.000    0.923
# 1      0.000     0.078    0.922
# 2      0.000     0.000    1.000
# 3      0.142     0.000    0.858
# 4      0.112     0.000    0.888
# 5      0.000     0.000    1.000
# 6      0.000     0.000    1.000
# 7      0.000     0.000    1.000
# 8      0.000     0.080    0.920
# 9      0.158     0.000    0.842
# 10     0.142     0.000    0.858
# 11     0.000     0.077    0.923
# 12     0.000     0.000    1.000
# 13     0.000     0.062    0.938
# 14     0.000     0.000    1.000
# 15     0.000     0.000    1.000
# 16     0.147     0.062    0.791
# 17     0.129     0.074    0.797
# 18     0.000     0.233    0.767
# 19     0.000     0.000    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_sentiments_df = pd.DataFrame(ethereum_sentiments)
ethereum_sentiments_df
# Out:
#                                                  text        date  compound  \
# 0   Blockchain startup MonoX Finance said on Wedne...  2021-12-02   -0.0516
# 1   White Castle double cheeseburger.Erin McDowell...  2021-12-10    0.0000
# 2   Crypto Street Restaurant, Clearwater Beach, Fl...  2021-12-30   -0.1531
# 3   Nicholas Merten , an expert in cryptography, p...  2021-12-10    0.4939
# 4   While people around the world still searched f...  2021-12-08    0.3612
# 5   The wait is finally over. After a year-long de...  2021-12-06    0.4019
# 6   MicroStrategy CEO Michael SaylorJoe Raedle/Get...  2021-12-06    0.2732
# 7   The Fine Print: The following comments are own...  2021-12-03   -0.0418
# 8   CryptoPunksRokas Tenys\r\n<ul><li>NFT sales ha...  2021-12-29    0.0000
# 9   The U.S. Captioning Company and the British In...  2021-12-07    0.2247
# 10  Amid the news of Bitcoin's price plunge on Sat...  2021-12-06   -0.5849
# 11  I own some cryptocurrencya decision which bega...  2021-12-06    0.4497
# 12  Representations of cryptocurrencies Bitcoin, E...  2021-12-20    0.0000
# 13  In the future, luxury brands may have storefro...  2021-12-26    0.0000
# 14  A representation of the virtual cryptocurrency...  2021-12-04    0.0000
# 15  Dec 4 (Reuters) - Bitcoin dropped 8.4% to $49,...  2021-12-04   -0.3818
# 16  Representation of cryptocurrency bitcoin is se...  2021-12-12    0.0000
# 17  Dec 3 (Reuters) - Bitcoin plunged 5.5% to $53,...  2021-12-03   -0.3818
# 18  A representation of the virtual cryptocurrency...  2021-12-28    0.0000
# 19  "We have identified a large-scale security bre...  2021-12-06    0.5859
#
#     positive  negative  neutral
# 0      0.074     0.079    0.847
# 1      0.000     0.000    1.000
# 2      0.000     0.060    0.940
# 3      0.119     0.000    0.881
# 4      0.070     0.000    0.930
# 5      0.155     0.115    0.729
# 6      0.111     0.075    0.814
# 7      0.079     0.086    0.835
# 8      0.000     0.000    1.000
# 9      0.058     0.000    0.942
# 10     0.000     0.109    0.891
# 11     0.078     0.000    0.922
# 12     0.000     0.000    1.000
# 13     0.000     0.000    1.000
# 14     0.000     0.000    1.000
# 15     0.000     0.080    0.920
# 16     0.000     0.000    1.000
# 17     0.000     0.077    0.923
# 18     0.000     0.000    1.000
# 19     0.156     0.000    0.844

# %%
# Describe the Bitcoin Sentiment
bitcoin_sentiments_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.046185   0.045350   0.033300   0.921350
# std     0.376374   0.065246   0.057897   0.079962
# min    -0.796400   0.000000   0.000000   0.767000
# 25%    -0.079550   0.000000   0.000000   0.858000
# 50%     0.000000   0.000000   0.000000   0.923000
# 75%     0.385600   0.116250   0.065000   1.000000
# max     0.585900   0.158000   0.233000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_sentiments_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.059775   0.045000   0.034050   0.920900
# std     0.307503   0.056386   0.044194   0.077524
# min    -0.584900   0.000000   0.000000   0.729000
# 25%    -0.044250   0.000000   0.000000   0.872500
# 50%     0.000000   0.000000   0.000000   0.926500
# 75%     0.295200   0.078250   0.077500   1.000000
# max     0.585900   0.156000   0.115000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin had the highest mean positive score.
#
# Q: Which coin had the highest compound score?
#
# A: Both bitcoin and etherum had max compound socre of 0.5859.
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin has the hightest positive score at .158

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)

    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the punctuation from text
    words = list(filter(lambda t: t not in punctuation, words))
   
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_sentiments_df["tokens"] = bitcoin_sentiments_df.text.apply(tokenizer)
bitcoin_sentiments_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Musk.MARK RALSTON/AFP via Getty Images\r\nElon...  2021-12-29    0.3612
# 1  Image source, AFP via Getty Images\r\nImage ca...  2021-12-12   -0.4019
# 2  The plant opening northeast of Niagara Falls t...  2021-12-06    0.0000
# 3  Dec 23 (Reuters) - The U.S. Securities and Exc...  2021-12-23    0.5859
# 4  People aren't done hijacking major politicians...  2021-12-12    0.5267
#
#    positive  negative  neutral  \
# 0     0.077     0.000    0.923
# 1     0.000     0.078    0.922
# 2     0.000     0.000    1.000
# 3     0.142     0.000    0.858
# 4     0.112     0.000    0.888
#
#                                               tokens
# 0  [Musk.MARK, RALSTON/AFP, via, Getty, Images, E...
# 1  [Image, source, AFP, via, Getty, Images, Image...
# 2  [The, plant, opening, northeast, of, Niagara, ...
# 3  [Dec, 23, Reuters, The, U.S., Securities, and,...
# 4  [People, are, n't, done, hijacking, major, pol...

# %%
# Create a new tokens column for Ethereum
ethereum_sentiments_df["tokens"] = ethereum_sentiments_df.text.apply(tokenizer)
ethereum_sentiments_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Blockchain startup MonoX Finance said on Wedne...  2021-12-02   -0.0516
# 1  White Castle double cheeseburger.Erin McDowell...  2021-12-10    0.0000
# 2  Crypto Street Restaurant, Clearwater Beach, Fl...  2021-12-30   -0.1531
# 3  Nicholas Merten , an expert in cryptography, p...  2021-12-10    0.4939
# 4  While people around the world still searched f...  2021-12-08    0.3612
#
#    positive  negative  neutral  \
# 0     0.074     0.079    0.847
# 1     0.000     0.000    1.000
# 2     0.000     0.060    0.940
# 3     0.119     0.000    0.881
# 4     0.070     0.000    0.930
#
#                                               tokens
# 0  [Blockchain, startup, MonoX, Finance, said, on...
# 1  [White, Castle, double, cheeseburger.Erin, McD...
# 2  [Crypto, Street, Restaurant, Clearwater, Beach...
# 3  [Nicholas, Merten, an, expert, in, cryptograph...
# 4  [While, people, around, the, world, still, sea...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
def process_text(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(bitcoin_articles))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in words if word.lower() not in sw]
    return output
processed = process_text(article)
bitcoin_bigram_counts = Counter(ngrams(processed, n=2))

# %%
# Generate the Ethereum N-grams where N=2
def process_text(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(ethereum_articles))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in words if word.lower() not in sw]
    return output

processed2 = process_text(article)
ethereum_bigram_counts = Counter(ngrams(processed2, n=2))

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
print(bitcoin_gram_counts.most_common(10))
# Out:
# [(('The', 'plant'), 1), (('plant', 'opening'), 1), (('opening', 'northeast'), 1), (('northeast', 'of'), 1), (('of', 'Niagara'), 1), (('Niagara', 'Falls'), 1), (('Falls', 'this'), 1), (('this', 'month'), 1), (('month', 'in'), 1), (('in', 'Somerset'), 1)]

# %%
# Use token_count to get the top 10 words for Ethereum
print(ethereum_gram_counts.most_common(10))
# Out:
# [(('Crypto', 'Street'), 2), (('Clearwater', 'Beach'), 2), (('Beach', 'Florida'), 2), (('Street', 'Restaurant'), 1), (('Restaurant', 'Clearwater'), 1), (('Florida', 'ClwBeachCrypto/Twitter'), 1), (('ClwBeachCrypto/Twitter', 'A'), 1), (('A', 'new'), 1), (('new', 'restaurant'), 1), (('restaurant', 'in'), 1)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [10.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(processed))
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(processed2))
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8.2)
# Requirement already satisfied: setuptools in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.12)
# Requirement already satisfied: jinja2 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: colorama in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: importlib-metadata in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\margee\anaconda3\envs\nlpenv\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_NER = bitcoin_sentiments_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(bitcoin_NER)
doc.ents

# Add a title to the document
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Getty Images ORG
# Elon Musk PERSON
# Nick Szabo PERSON
# Satoshi Nakamoto PERSON
# AFP ORG
# Getty Images ORG
# Modi GPE
# more than 70 million MONEY
# Twitter PRODUCT
# Indian NORP
# Narendra Modi's PERSON
# Twitter PRODUCT
# India GPE
# Niagara Falls PERSON
# this month DATE
# Somerset GPE
# N.Y. GPE
# $550 million MONEY
# Terawulf DATE
# 150-megawatt QUANTITY
# 23 CARDINAL
# Reuters ORG
# The U.S. Securities and Exchange Commission ORG
# two CARDINAL
# Twitter PRODUCT
# TechCrunch ORG
# Indian NORP
# Narendra Modi's PERSON
# Twitter PRODUCT
# November 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationDec PERSON
# 12 CARDINAL
# Reuters ORG
# Sunday DATE
# above $50,000 MONEY
# Monday DATE
# Florida GPE
# half CARDINAL
# Bitcoin PERSON
# October 19, 2021 DATE
# REUTERS ORG
# Reuters ORG
# 6.13% PERCENT
# 47,606.92 MONEY
# Tuesday DATE
# 4 CARDINAL
# Reuters ORG
# 8.4% PERCENT
# 49,228.82 MONEY
# 20:01 CARDINAL
# Saturday DATE
# 4,514.87 MONEY
# Bitcoin PERSON
# 28.7% PERCENT
# fifth ORDINAL
# Saturday DATE
# nearly a billion dollars MONEY
# fifth ORDINAL
# Saturday DATE
# nearly a billion dollars MONEY
# 3 CARDINAL
# Reuters ORG
# 5.5% PERCENT
# 53,435.9 MONEY
# 22:04 CARDINAL
# Friday DATE
# 3,112.06 MONEY
# Bitcoin PERSON
# 22.6% PERCENT
# Bitcoin PERSON
# October 19, 2021 DATE
# REUTERS ORG
# Reuters ORG
# 9.29% PERCENT
# 48,752.15 MONEY
# almost 5% PERCENT
# Monday DATE
# the start of the week DATE
# a bruising weekend DATE
# one CARDINAL
# fifth ORDINAL
# this week DATE
# Florida GPE
# half CARDINAL
# this week DATE
# Florida GPE
# half CARDINAL
# CIA ORG
# 10 minutes or so TIME
# David Gerard PERSON
# daily DATE
# Cryptocurrencies ORG
# this weekend DATE
# 14% PERCENT
# the weekend DATE
# $42K MONEY
# 9000 MONEY
# an hour TIME
# Satoshi PERSON
# Getty ORG
# Monday DATE

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Musk.MARK RALSTON/AFP via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  seems to agree with many that hyper-secret cryptocurrency expert
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nick Szabo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  could be
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakamoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the mysterious creator of the digital currency… [+1467 chars]Image source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Image caption,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Modi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Prime Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Narendra Modi's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  account was hacked with a message saying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ha… [+854 chars]The plant opening northeast of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niagara Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Somerset
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N.Y.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , is part of a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $550 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  project by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Terawulf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a Bitcoin mining company. The project also includes a proposed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     150-megawatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  … [+1514 chars]Dec
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The U.S. Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vetoed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  proposals to offer bitcoin exchange-traded funds, dealing a blow to market participants who h

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['Modi', 'India', 'Somerset', 'N.Y.', 'Florida', 'Florida', 'Florida']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_NER = ethereum_sentiments_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(ethereum_NER)
doc.ents

# Add a title to the document
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Wednesday DATE
# $31 million MONEY
# Ars Te ORG
# Castle PRODUCT
# Erin McDowell/Insider PERSON
# White Castle FAC
# Twitter PRODUCT
# Street Restaurant PERSON
# Clearwater Beach GPE
# Florida.@ClwBeachCrypto/Twitter ORG
# Clearwater Beach GPE
# Florida GPE
# Crypto Street Restaura PERSON
# Merten PERSON
# May 2018 DATE
# Google ORG
# Search GPE
# 2021 DATE
# Squid Game ORG
# year-long DATE
# Xboxs ORG
# Halo Infinite ORG
# Michael SaylorJoe Raedle/Getty Images PERSON
# ETF ORG
# CryptoPunksRokas Tenys ORG
# a breakthrough year DATE
# $14 billion MONEY
# 2021.</li><li CARDINAL
# NFT ORG
# the British Institute of Verbatim Reporters ORG
# Bitcoin PERSON
# Saturday DATE
# the weekend DATE
# $196 million MONEY
# Bitmar GPE
# Bitcoin, Ethereum ORG
# DogeCoin ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/File Photo PERSON
# DUBAI ORG
# Bitcoin PERSON
# October 19, 2021 DATE
# REUTERS ORG
# Reuters ORG
# 9.29% PERCENT
# 48,752.15 MONEY
# 4 CARDINAL
# Reuters ORG
# 8.4% PERCENT
# 49,228.82 MONEY
# 20:01 CARDINAL
# Saturday DATE
# 4,514.87 MONEY
# Bitcoin PERSON
# 28.7% PERCENT
# November 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationDec PERSON
# 12 CARDINAL
# Reuters ORG
# Sunday DATE
# above $50,000 MONEY
# 3 CARDINAL
# Reuters ORG
# 5.5% PERCENT
# 53,435.9 MONEY
# 22:04 CARDINAL
# Friday DATE
# 3,112.06 MONEY
# Bitcoin PERSON
# 22.6% PERCENT
# Bitcoin PERSON
# October 19, 2021 DATE
# REUTERS ORG
# Reuters ORG
# 6.13% PERCENT
# 47,606.92 MONEY
# Tuesday DATE
# CNBC ORG
# $196 million MONEY
# BitMart ORG
# Satur PERSON

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Blockchain startup MonoX Finance said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that a hacker stole
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $31 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>This story originally appeared on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ars Te
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+4372 chars]White
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Castle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  double cheeseburger.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erin McDowell/Insider
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Fast food chain
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     White Castle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  announced on
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  that it registered a domain name with th… [+1012 chars]Crypto
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Street Restaurant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clearwater Beach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida.@ClwBeachCrypto/Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>A new restaurant in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clearwater Beach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto Street Restaura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+2203 chars]Nicholas
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  , an expert in cryptography, predicts that the digital currency ethereum will overtake bitcoin in the market after reaching its highest value since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . He clarified that these e… [+769 chars]While people around the world still searched for information about the COVID-19 pandemic, other topics dominated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's Year in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Search
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  like cricket and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Squid Game
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Matches for the T20 Worl… [+2053 chars]The wait is finally over. After a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year-long
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  delay,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xboxs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  iconic hero, Master Chief, is back. With
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Halo Infinite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , there are new toys and fight mechanics, while many players will also benefit from majo… [+4439 chars]MicroStrategy CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael SaylorJoe Raedle/Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: mi

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['Clearwater Beach', 'Clearwater Beach', 'Florida', 'Search', 'Bitmar']

# %% [markdown]
# ---
